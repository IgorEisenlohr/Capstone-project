# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorEisenlohr/Capstone-project/blob/main/MVP_sprint_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
url = 'https://raw.githubusercontent.com/IgorEisenlohr/MVP-sprint-2/main/usa_real_state/realtor-data.csv'
df = pd.read_csv(url, parse_dates=['sold_date'])
df.head()
# Out:
#      status     price  bed  bath  acre_lot  \
# 0  for_sale  105000.0  3.0   2.0      0.12
# 1  for_sale   80000.0  4.0   2.0      0.08
# 2  for_sale   67000.0  2.0   1.0      0.15
# 3  for_sale  145000.0  4.0   2.0      0.10
# 4  for_sale   65000.0  6.0   2.0      0.05
#
#                                         full_address  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state  \
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# ...

# %%
df.shape
# Out:
# (512159, 12)

# %%
df.isnull().sum()
# Out:
# status               0
# price                0
# bed              98937
# bath             95218
# acre_lot        104979
# full_address         0
# street             616
# city                59
# state                0
# zip_code           197
# house_size      116466
# sold_date       309652
# dtype: int64

# %% [markdown]
# # Deep Learning

# %%
# !git clone https://github.com/IgorEisenlohr/MVP-sprint-2.git
# Out:
# Cloning into 'MVP-sprint-2'...
# remote: Enumerating objects: 5840, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5840 (delta 0), reused 3 (delta 0), pack-reused 5836
# Receiving objects: 100% (5840/5840), 1.13 GiB | 36.20 MiB/s, done.
# Updating files: 100% (5857/5857), done.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

# %%
img = Image.open('/content/MVP-sprint-2/chest_xray/train/NORMAL/IM-0115-0001.jpeg')
img = img.resize((255,255))

img2 = Image.open('/content/MVP-sprint-2/chest_xray/train/PNEUMONIA/person1000_bacteria_2931.jpeg')
img2 = img2.resize((255,255))

plt.subplot(121)
plt.title('NORMAL')
plt.imshow(img, cmap='gray')

plt.subplot(122)
plt.title('PNEUMONIA')
plt.imshow(img2, cmap='gray')
